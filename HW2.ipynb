# %%
import matplotlib.pyplot as plt
import seaborn as sb
passengers = [700, 650, 600, 560, 500, 450, 600, 700, 800, 850, 900, 920]
month = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
flights_df = sb.load_dataset("flights")
flights_df
plt.plot(month, passengers)
plt.show()

# %%
passengers1949 = [112, 118, 132, 129, 121, 119, 130, 140, 142, 137, 127, 150]
plt.plot(month, passengers1949)
plt.show()

# %%
years = [1949, 1952, 1956, 1960, 1965, 1969, 1973, 1980, 1990, 2010, 2024]
pasengers = [112, 300, 330, 606, 612, 640, 660, 690, 757, 900, 1100]
plt.plot(years, pasengers)
plt.show()

# %%
flights_df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
years = flights_df["year"]
months = flights_df["month"]
passengers = flights_df["passengers"]
plt.plot(years, passengers)
plt.show()

# %%
plt.scatter(years, passengers)
plt.show()

# %%
plt.plot(months, passengers)
plt.show()

# %%
plt.scatter(months, passengers)
plt.show()
